# %%
from datetime import datetime
import pandas as pd
# import ezodf
from pydantic import BaseModel
import requests
import folium
import math
import numpy as np
from typing import List, Optional, Dict, Tuple
from collections import Counter

# ------------------------- Models -------------------------
class Point(BaseModel):
    latitude: float
    longitude: float
    timestamp: float  # Unix timestamp
    yaw_rate: float = 0.0

class LanePosition(BaseModel):
    latitude: float
    longitude: float
    lane_number: int
    confidence: float
    lateral_offset: float
    road_bearing: float
    timestamp: float

class RoadGeometry(BaseModel):
    centerline_lat: float
    centerline_lon: float
    bearing: float
    total_lanes: int = 3
    lane_width: float = 3.5
    curvature: float = 0.0

# ------------------------- Extractor -------------------------
def extract_points_from_csv(file_path: str, lat_col: str = "lat", lon_col: str = "long", 
                           time_col: str = "TimeStamp", yaw_col: str = "yawRate") -> list[Point]:
    df = pd.read_csv(file_path)
    points = []
    base_date = datetime(2025, 2, 21).date()
    
    for _, row in df.iterrows():
        try:
            full_datetime_str = f"{base_date} {row[time_col]}"
            full_datetime = datetime.strptime(full_datetime_str, "%Y-%m-%d %H:%M:%S.%f")
            timestamp = full_datetime.timestamp()
            yawRate = float(row[yaw_col]) if yaw_col in row else 0.0
            lat = float(row[lat_col])
            long = float(row[lon_col])
            point = Point(latitude=lat, longitude=long, timestamp=timestamp, yaw_rate=yawRate)
            points.append(point)
        except (ValueError, TypeError, KeyError):
            continue
    return points

def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371000
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = phi2 - phi1
    dlambda = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1)*math.cos(phi2)*math.sin(dlambda/2)**2
    return R * (2 * math.atan2(math.sqrt(a), math.sqrt(1 - a)))

# ------------------------- Calculations -------------------------
def calculate_road_bearing(p1: Point, p2: Point) -> float:
    lat1, lon1 = math.radians(p1.latitude), math.radians(p1.longitude)
    lat2, lon2 = math.radians(p2.latitude), math.radians(p2.longitude)
    dlon = lon2 - lon1
    y = math.sin(dlon) * math.cos(lat2)
    x = math.cos(lat1) * math.sin(lat2) - math.sin(lat1) * math.cos(lat2) * math.cos(dlon)
    return math.atan2(y, x)

def calculate_lateral_offset(gps_point: Point, matched_point: Tuple[float, float], road_bearing: float) -> float:
    # Calculate the perpendicular distance from GPS point to road centerline
    lat_diff = gps_point.latitude - matched_point[0]
    lon_diff = gps_point.longitude - matched_point[1]
    
    # Convert to meters
    lat_meters = lat_diff * 111319.9
    lon_meters = lon_diff * 111319.9 * math.cos(math.radians(gps_point.latitude))
    
    # Project onto perpendicular to road direction
    # Positive offset = right side of road, negative = left side
    lateral_offset = -lat_meters * math.sin(road_bearing) + lon_meters * math.cos(road_bearing)
    
    return lateral_offset

def detect_lane_change(yaw_rates: List[float], threshold: float = 0.08) -> bool:
    """More sensitive lane change detection"""
    if len(yaw_rates) < 3:
        return False
    
    # Check for sustained yaw rate or sudden changes
    avg_yaw_rate = sum(abs(yr) for yr in yaw_rates) / len(yaw_rates)
    max_yaw_rate = max(abs(yr) for yr in yaw_rates)
    
    return avg_yaw_rate > threshold or max_yaw_rate > (threshold * 2)

def assign_lane_probabilistic(lateral_offset: float, road_geometry: RoadGeometry, 
                               yaw_rates: List[float], confidence_factor: float = 1.0, 
                               previous_lane: Optional[int] = None) -> Tuple[int, float]:
    """Fixed lane assignment with better probability distribution"""
    
    total_lanes = road_geometry.total_lanes
    lane_width = road_geometry.lane_width
    
    # Calculate probabilities for each lane
    lane_probabilities = []
    
    for lane_num in range(1, total_lanes + 1):
        # Lane center offset from road centerline
        # Lane 1 = leftmost, Lane 3 = rightmost (for 3-lane road)
        lane_center_offset = (lane_num - (total_lanes + 1) / 2) * lane_width
        
        # Distance from GPS point to lane center
        distance = abs(lateral_offset - lane_center_offset)
        
        # Gaussian probability based on distance
        sigma = lane_width / 3.0  # Standard deviation
        
        # Adjust sigma during lane changes
        if detect_lane_change(yaw_rates):
            sigma *= 1.8  # Increase uncertainty during lane changes
        
        # Calculate probability
        prob = math.exp(-0.5 * (distance / sigma) ** 2)
        
        # Small continuity bonus for previous lane (reduced from 1.3 to 1.1)
        if previous_lane and lane_num == previous_lane:
            prob *= 1.1
            
        lane_probabilities.append(prob)
    
    # Normalize probabilities
    total_prob = sum(lane_probabilities)
    if total_prob == 0:
        # Fallback to center lane if no good match
        return 2, 0.1
    
    lane_probabilities = [p / total_prob for p in lane_probabilities]
    
    # Find best lane
    best_lane_idx = lane_probabilities.index(max(lane_probabilities))
    best_lane = best_lane_idx + 1
    confidence = max(lane_probabilities)
    
    # Debug output for bias checking
    print(f"DEBUG: Lateral offset: {lateral_offset:.3f}m, Lane probs: {[f'{p:.3f}' for p in lane_probabilities]}, Best: {best_lane}")
    
    # Reduce over-reliance on previous lane if confidence is reasonable
    if confidence > 0.5:
        return best_lane, confidence
    
    # Only use previous lane as fallback if confidence is very low
    if confidence < 0.3 and previous_lane:
        return previous_lane, confidence * 0.7
    
    return best_lane, confidence

def calculate_lane_coordinates(road_geometry: RoadGeometry, lane_number: int, dynamic_offset: float = 0.0) -> Tuple[float, float]:
    """Calculate the lat/lon coordinates for a specific lane"""
    # Lane center offset from road centerline
    lane_center_offset = (lane_number - (road_geometry.total_lanes + 1) / 2) * road_geometry.lane_width
    total_offset = lane_center_offset + dynamic_offset
    
    # Perpendicular bearing to road direction
    bearing = road_geometry.bearing + math.pi/2
    
    # Convert offset to lat/lon
    lat_offset = (total_offset * math.cos(bearing)) / 111319.9
    lon_offset = (total_offset * math.sin(bearing)) / (111319.9 * math.cos(math.radians(road_geometry.centerline_lat)))
    
    return road_geometry.centerline_lat + lat_offset, road_geometry.centerline_lon + lon_offset

# ------------------------- Fixed Lane Mapping -------------------------
def process_lane_mapping(points: List[Point], osrm_data: Dict, start_index: int = 0) -> List[Tuple[int, LanePosition]]:
    """
    Completely fixed version that processes all valid points
    """
    lane_positions = []
    tracepoints = osrm_data.get("tracepoints", [])
    
    if len(tracepoints) != len(points):
        print(f"WARNING: Mismatch - {len(points)} GPS points but {len(tracepoints)} tracepoints")
    
    previous_lane = None
    lane_history = []

    for i, point in enumerate(points):
        global_index = start_index + i

        # Skip if this point has the same coordinates as the previous point
        if i > 0:
            prev_point = points[i - 1]
            if (point.latitude == prev_point.latitude) and (point.longitude == prev_point.longitude):
                print(f"DEBUG: GPS {global_index} - Skipped duplicate coordinate")
                continue

        # Skip if no corresponding tracepoint
        if i >= len(tracepoints):
            print(f"DEBUG: GPS {global_index} - No tracepoint available")
            continue
            
        tracepoint = tracepoints[i]
        
        # Skip if tracepoint is None or has no location
        if not tracepoint or not tracepoint.get("location"):
            print(f"DEBUG: GPS {global_index} - Invalid tracepoint: {tracepoint}")
            continue

        matched_lon, matched_lat = tracepoint["location"]
        
        # Calculate road bearing with better logic
        road_bearing = 0.0
        bearing_calculated = False
        
        # Try to get bearing from next point
        if i < len(points) - 1 and i + 1 < len(tracepoints):
            next_tp = tracepoints[i + 1]
            if next_tp and next_tp.get("location"):
                next_lon, next_lat = next_tp["location"]
                # Only calculate if points are sufficiently different
                if haversine_distance(matched_lat, matched_lon, next_lat, next_lon) > 1.0:
                    road_bearing = calculate_road_bearing(
                        Point(latitude=matched_lat, longitude=matched_lon, timestamp=0),
                        Point(latitude=next_lat, longitude=next_lon, timestamp=0)
                    )
                    bearing_calculated = True
        
        # Try to get bearing from previous point if next didn't work
        if not bearing_calculated and i > 0:
            prev_tp = tracepoints[i - 1]
            if prev_tp and prev_tp.get("location"):
                prev_lon, prev_lat = prev_tp["location"]
                if haversine_distance(prev_lat, prev_lon, matched_lat, matched_lon) > 1.0:
                    road_bearing = calculate_road_bearing(
                        Point(latitude=prev_lat, longitude=prev_lon, timestamp=0),
                        Point(latitude=matched_lat, longitude=matched_lon, timestamp=0)
                    )
                    bearing_calculated = True

        # Create road geometry
        road_geometry = RoadGeometry(
            centerline_lat=matched_lat,
            centerline_lon=matched_lon,
            bearing=road_bearing
        )

        # Calculate lateral offset
        lateral_offset = calculate_lateral_offset(point, (matched_lat, matched_lon), road_bearing)
        
        # Get recent yaw rates for lane change detection
        recent_yaw_rates = []
        for j in range(max(0, i - 2), min(len(points), i + 3)):
            recent_yaw_rates.append(points[j].yaw_rate)
        
        # Assign lane with improved algorithm
        lane_number, confidence = assign_lane_probabilistic(
            lateral_offset, road_geometry, recent_yaw_rates, 1.0, previous_lane
        )
        
        # Apply minimal temporal smoothing
        lane_history.append(lane_number)
        if len(lane_history) > 3:  # Reduced from 5 to 3
            lane_history.pop(0)
            
        # Only smooth if we have enough history and confidence is very low
        if len(lane_history) >= 3 and confidence < 0.4:
            lane_counts = Counter(lane_history)
            most_common_lane = lane_counts.most_common(1)[0][0]
            
            if lane_number != most_common_lane:
                print(f"DEBUG: GPS {global_index} - Smoothing lane {lane_number} -> {most_common_lane}")
                lane_number = most_common_lane
                confidence *= 0.9

        # Accept points with reasonable confidence
        if confidence > 0.2:  # Lowered threshold to include more points
            lane_lat, lane_lon = calculate_lane_coordinates(road_geometry, lane_number)

            lane_position = LanePosition(
                latitude=lane_lat,
                longitude=lane_lon,
                lane_number=lane_number,
                confidence=confidence,
                lateral_offset=lateral_offset,
                road_bearing=road_bearing,
                timestamp=point.timestamp
            )
            
            lane_positions.append((global_index, lane_position))
            previous_lane = lane_number
            
            print(f"DEBUG: GPS {global_index} - Mapped to lane {lane_number} (conf: {confidence:.3f}, offset: {lateral_offset:.3f}m)")
        else:
            print(f"DEBUG: GPS {global_index} - Skipped due to low confidence: {confidence:.3f}")

    return lane_positions

# ------------------------- Improved Map Visualization -------------------------
def create_lane_map(points: List[Point], indexed_lane_positions: List[Tuple[int, LanePosition]]) -> folium.Map:
    if not points:
        return folium.Map()
    
    # Center map on first point
    fmap = folium.Map(location=[points[0].latitude, points[0].longitude], zoom_start=17)
    lane_colors = {1: 'red', 2: 'blue', 3: 'green', 4: 'orange', 5: 'purple'}

    # Plot all GNSS points (small purple circles)
    for i, point in enumerate(points):
        folium.CircleMarker(
            [point.latitude, point.longitude],
            radius=2,
            color='purple',
            fill=True,
            fill_color='purple',
            fillOpacity=0.6,
            popup=f"GNSS Point {i}: {point.latitude:.6f}, {point.longitude:.6f}"
        ).add_to(fmap)

    # Plot lane-mapped points
    mapped_count = 0
    lane_distribution = Counter()
    
    for gnss_index, lp in indexed_lane_positions:
        if gnss_index >= len(points):
            continue
            
        original_point = points[gnss_index]
        lane_distribution[lp.lane_number] += 1
        
        # Create lane-mapped point marker
        folium.CircleMarker(
            [lp.latitude, lp.longitude],
            radius=2,
            color=lane_colors.get(lp.lane_number, 'black'),
            fill=True,
            fill_color=lane_colors.get(lp.lane_number, 'black'),
            fillOpacity=0.8,
            popup=(f"GNSS #{gnss_index} -> Lane {lp.lane_number}<br>"
                   f"Original: {original_point.latitude:.6f}, {original_point.longitude:.6f}<br>"
                   f"Offset: {lp.lateral_offset:.2f} m<br>"
                   f"Confidence: {lp.confidence:.2f}<br>"
                   f"Bearing: {math.degrees(lp.road_bearing):.1f}°")
        ).add_to(fmap)
        
        # Draw line connecting GNSS point to lane-mapped point
        folium.PolyLine(
            [[original_point.latitude, original_point.longitude], [lp.latitude, lp.longitude]],
            color=lane_colors.get(lp.lane_number, 'black'),
            weight=1,
            opacity=0.5
        ).add_to(fmap)
        
        mapped_count += 1

    # Add statistics to legend
    total_points = len(points)
    mapping_rate = (mapped_count / total_points * 100) if total_points > 0 else 0
    
    legend_html = f'''
    <div style="position: fixed; 
                top: 10px; right: 10px; width: 200px; height: 180px; 
                background-color: white; border:2px solid grey; z-index:9999; 
                font-size:12px; padding: 10px">
    <p><b>Lane Mapping Results</b></p>

    <p><i class="fa fa-circle" style="color:purple"></i> GNSS Points</p>
    <p><i class="fa fa-circle" style="color:red"></i> Lane 1: {lane_distribution[1]}</p>
    <p><i class="fa fa-circle" style="color:blue"></i> Lane 2: {lane_distribution[2]}</p>
    <p><i class="fa fa-circle" style="color:green"></i> Lane 3: {lane_distribution[3]}</p>
    </div>
    '''
    fmap.get_root().html.add_child(folium.Element(legend_html))

    return fmap

# ------------------------- Main Process -------------------------
def process_with_lane_mapping(file_path: str):
    """Main processing function with improved error handling"""
    print("Extracting GPS points from ODS file...")
    points = extract_points_from_csv(file_path)
    print(f"Extracted {len(points)} GPS points")
    
    if len(points) < 2:
        print("ERROR: Need at least 2 GPS points")
        return [], [], None
    
    BATCH_SIZE = 100
    
    all_lane_positions = []
    
    print("Processing GPS points in batches...")
    
    for start in range(0, len(points), BATCH_SIZE):
        batch = points[start:start + BATCH_SIZE]
        batch_end = start + len(batch)
        
        print(f"Processing batch {start//BATCH_SIZE + 1}: GPS points {start} to {batch_end-1}")
        
        if len(batch) < 2:
            print("Batch too small, skipping...")
            continue
            
        try:
            # Prepare OSRM request
            coord_str = ';'.join([f"{p.longitude},{p.latitude}" for p in batch])
            radius_str = ';'.join(['50'] * len(batch))
            url = f"http://127.0.0.1:5001/match/v1/driving/{coord_str}?overview=full&geometries=geojson&gaps=ignore&radiuses={radius_str}"
            
            # Make request
            response = requests.get(url, timeout=30)
            
            if response.status_code == 200:
                data = response.json()
                
                if 'tracepoints' in data:
                    print(f"OSRM returned {len(data['tracepoints'])} tracepoints for {len(batch)} GPS points")
                    
                    # Process this batch
                    batch_lane_positions = process_lane_mapping(batch, data, start)
                    all_lane_positions.extend(batch_lane_positions)
                    
                    print(f"Mapped {len(batch_lane_positions)} points in this batch")
                else:
                    print("ERROR: No tracepoints in OSRM response")
            else:
                print(f"ERROR: OSRM request failed with status {response.status_code}")
                
        except Exception as e:
            print(f"ERROR in batch starting at {start}: {e}")
            continue

    print(f"\nTotal processing complete:")
    print(f"- Input GPS points: {len(points)}")
    print(f"- Successfully mapped: {len(all_lane_positions)}")
    print(f"- Mapping rate: {len(all_lane_positions)/len(points)*100:.1f}%")
    
    # Create visualization
    print("Creating map visualization...")
    fmap = create_lane_map(points, all_lane_positions)
    
    return points, all_lane_positions, fmap

# Execute the processing
if __name__ == "__main__":
    file_path = r"harman_clean.csv"
    points, lane_positions, fmap = process_with_lane_mapping(file_path)
    
    # Print final statistics
    if lane_positions:
        lane_dist = Counter([lp[1].lane_number for lp in lane_positions])
        print(f"\nFinal lane distribution:")
        for lane in sorted(lane_dist.keys()):
            print(f"Lane {lane}: {lane_dist[lane]} points ({lane_dist[lane]/len(lane_positions)*100:.1f}%)")
    
    print("\nDone! Check the map visualization.")
    display(fmap)
# Out:
# Extracting GPS points from ODS file...
# Extracted 2591 GPS points
# Processing GPS points in batches...
# Processing batch 1: GPS points 0 to 99
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: -6.798m, Lane probs: ['1.000', '0.000', '0.000'], Best: 1
# DEBUG: GPS 0 - Mapped to lane 1 (conf: 1.000, offset: -6.798m)
# DEBUG: GPS 1 - Skipped duplicate coordinate
# DEBUG: GPS 2 - Skipped duplicate coordinate
# DEBUG: GPS 3 - Skipped duplicate coordinate
# DEBUG: GPS 4 - Skipped duplicate coordinate
# DEBUG: GPS 5 - Skipped duplicate coordinate
# DEBUG: GPS 6 - Skipped duplicate coordinate
# DEBUG: GPS 7 - Skipped duplicate coordinate
# DEBUG: GPS 8 - Skipped duplicate coordinate
# DEBUG: Lateral offset:
- Skipped duplicate coordinate
# DEBUG: Lateral offset: -10.031m, Lane probs: ['0.999', '0.001', '0.000'], Best: 1
# DEBUG: GPS 289 - Mapped to lane 1 (conf: 0.999, offset: -10.031m)
# DEBUG: GPS 290 - Skipped duplicate coordinate
# DEBUG: GPS 291 - Skipped duplicate coordinate
# DEBUG: GPS 292 - Skipped duplicate coordinate
# DEBUG: GPS 293 - Skipped duplicate coordinate
# DEBUG: GPS 294 - Skipped duplicate coordinate
# DEBUG: GPS 295 - Skipped duplicate coordinate
# DEBUG: GPS 296 - Skipped duplicate coordinate
# DEBUG: GPS 297 - Skipped duplicate coordinate
# DEBUG: GPS 298 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -9.039m, Lane probs: ['0.997', '0.003', '0.000'], Best: 1
# DEBUG: GPS 299 - Mapped to lane 1 (conf: 0.997, offset: -9.039m)
# Mapped 6 points in this batch
# Processing batch 4: GPS points 300 to 399
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: -9.039m, Lane probs: ['0.997', '0.003', '0.000'], Best: 1
# DEBUG: GPS 300 - Mapped to lane 1 (conf: 0.997, offset: -9.039m)
# DEBUG: GPS 301 - Skipped duplicate coordinate
# DEBUG: GPS 302 - Skipped duplicate coordinate
# DEBUG: GPS 303 - Skipped duplicate coordinate
# DEBUG: GPS 304 - Skipped duplicate coordinate
# DEBUG: GPS 305 - Skipped duplicate coordinate
# DEBUG: GPS 306 - Skipped duplicate coordinate
# DEBUG: GPS 307 - Skipped duplicate coordinate
# DEBUG: GPS 308 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -8.965m, Lane probs: ['1.000', '0.000', '0.000'], Best: 1
# DEBUG: GPS 309 - Mapped to lane 1 (conf: 1.000, offset: -8.965m)
# DEBUG: GPS 310 - Skipped duplicate coordinate
# DEBUG: GPS 311 - Skipped duplicate coordinate
# DEBUG: GPS 312 - Skipped duplicate coordinate
# DEBUG: GPS 313 - Skipped duplicate coordinate
# DEBUG: GPS 314 - Skipped duplicate coordinate
# DEBUG: GPS 315 - Skipped duplicate coordinate
# DEBUG: GPS 316 - Skipped duplicate coordinate
# DEBUG: GPS 317 - Skipped duplicate coordinate
# DEBUG: GPS 318 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -8.079m, Lane probs: ['0.994', '0.006', '0.000'], Best: 1
# DEBUG: GPS 319 - Mapped to lane 1 (conf: 0.994, offset: -8.079m)
# DEBUG: GPS 320 - Skipped duplicate coordinate
# DEBUG: GPS 321 - Skipped duplicate coordinate
# DEBUG: GPS 322 - Skipped duplicate coordinate
# DEBUG: GPS 323 - Skipped duplicate coordinate
# DEBUG: GPS 324 - Skipped duplicate coordinate
# DEBUG: GPS 325 - Skipped duplicate coordinate
# DEBUG: GPS 326 - Skipped duplicate coordinate
# DEBUG: GPS 327 - Skipped duplicate coordinate
# DEBUG: GPS 328 - Skipped duplicate coordinate
# DEBUG: Lateral offset:
- Skipped duplicate coordinate
# DEBUG: Lateral offset: -5.001m, Lane probs: ['0.935', '0.064', '0.000'], Best: 1
# DEBUG: GPS 379 - Mapped to lane 1 (conf: 0.935, offset: -5.001m)
# DEBUG: GPS 380 - Skipped duplicate coordinate
# DEBUG: GPS 381 - Skipped duplicate coordinate
# DEBUG: GPS 382 - Skipped duplicate coordinate
# DEBUG: GPS 383 - Skipped duplicate coordinate
# DEBUG: GPS 384 - Skipped duplicate coordinate
# DEBUG: GPS 385 - Skipped duplicate coordinate
# DEBUG: GPS 386 - Skipped duplicate coordinate
# DEBUG: GPS 387 - Skipped duplicate coordinate
# DEBUG: GPS 388 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -4.831m, Lane probs: ['0.927', '0.073', '0.000'], Best: 1
# DEBUG: GPS 389 - Mapped to lane 1 (conf: 0.927, offset: -4.831m)
# DEBUG: GPS 390 - Skipped duplicate coordinate
# DEBUG: GPS 391 - Skipped duplicate coordinate
# DEBUG: GPS 392 - Skipped duplicate coordinate
# DEBUG: GPS 393 - Skipped duplicate coordinate
# DEBUG: GPS 394 - Skipped duplicate coordinate
# DEBUG: GPS 395 - Skipped duplicate coordinate
# DEBUG: GPS 396 - Skipped duplicate coordinate
# DEBUG: GPS 397 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -4.819m, Lane probs: ['0.926', '0.074', '0.000'], Best: 1
# DEBUG: GPS 398 - Mapped to lane 1 (conf: 0.926, offset: -4.819m)
# DEBUG: GPS 399 - Skipped duplicate coordinate
# Mapped 11 points in this batch
# Processing batch 5: GPS points 400 to 499
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: -4.520m, Lane probs: ['0.900', '0.100', '0.001'], Best: 1
# DEBUG: GPS 400 - Mapped to lane 1 (conf: 0.900, offset: -4.520m)
# DEBUG: GPS 401 - Skipped duplicate coordinate
# DEBUG: GPS 402 - Skipped duplicate coordinate
# DEBUG: GPS 403 - Skipped duplicate coordinate
# DEBUG: GPS 404 - Skipped duplicate coordinate
# DEBUG: GPS 405 - Skipped duplicate coordinate
# DEBUG: GPS 406 - Skipped duplicate coordinate
# DEBUG: GPS 407 - Skipped duplicate coordinate
# DEBUG: GPS 408 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -4.462m, Lane probs: ['0.904', '0.095', '0.001'], Best: 1
# DEBUG: GPS 409 - Mapped to lane 1 (conf: 0.904, offset: -4.462m)
# DEBUG: GPS 410 - Skipped duplicate coordinate
# DEBUG: GPS 411 - Skipped duplicate coordinate
# DEBUG: GPS 412 - Skipped duplicate coordinate
# DEBUG: GPS 413 - Skipped duplicate coordinate
# DEBUG: GPS 414 - Skipped duplicate coordinate
# DEBUG: GPS 415 - Skipped duplicate coordinate
# DEBUG: GPS 416 - Skipped duplicate coordinate
# DEBUG: GPS 417 - Skipped duplicate coordinate
# DEBUG: GPS 418 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -3.599m, Lane probs: ['0.825', '0.173', '0.002'], Best: 1
# DEBUG: GPS 419 - Mapped to lane 1 (conf: 0.825, offset: -3.599m)
# DEBUG: GPS 420 - Skipped duplicate coordinate
# DEBUG: GPS 421 - Skipped duplicate coordinate
# DEBUG: GPS 422 - Skipped duplicate coordinate
# DEBUG: GPS 423 - Skipped duplicate coordinate
# DEBUG: GPS 424 - Skipped duplicate coordinate
# DEBUG: GPS 425 - Skipped duplicate coordinate
# DEBUG: GPS 426 - Skipped duplicate coordinate
# DEBUG: GPS 427 - Skipped duplicate coordinate
# DEBUG: GPS 428 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -3.247m, Lane probs: ['0.780', '0.216', '0.004'], Best: 1
# DEBUG: GPS 429 - Mapped to lane 1 (conf: 0.780, offset: -3.247m)
# DEBUG: GPS 430 - Skipped duplicate coordinate
# DEBUG: GPS 431 - Skipped duplicate coordinate
# DEBUG: GPS 432 - Skipped duplicate coordinate
# DEBUG: GPS 433 - Skipped duplicate coordinate
# DEBUG: GPS 434 - Skipped duplicate coordinate
# DEBUG: GPS 435 - Skipped duplicate coordinate
# DEBUG: GPS 436 - Skipped duplicate coordinate
# DEBUG: GPS 437 - Skipped duplicate coordinate
# DEBUG: GPS 438 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.603m, Lane probs: ['0.677', '0.313', '0.010'], Best: 1
# DEBUG: GPS 439 - Mapped to lane 1 (conf: 0.677, offset: -2.603m)
# DEBUG: GPS 440 - Skipped duplicate coordinate
# DEBUG: GPS 441 - Skipped duplicate coordinate
# DEBUG: GPS 442 - Skipped duplicate coordinate
# DEBUG: GPS 443 - Skipped duplicate coordinate
# DEBUG: GPS 444 - Skipped duplicate coordinate
# DEBUG: GPS 445 - Skipped duplicate coordinate
# DEBUG: GPS 446 - Skipped duplicate coordinate
# DEBUG: GPS 447 - Skipped duplicate coordinate
# DEBUG: GPS 448 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -1.469m, Lane probs: ['0.450', '0.511', '0.040'], Best: 2
# DEBUG: GPS 449 - Mapped to lane 2 (conf: 0.511, offset: -1.469m)
# DEBUG: GPS 450 - Skipped duplicate coordinate
# DEBUG: GPS 451 - Skipped duplicate coordinate
# DEBUG: GPS 452 - Skipped duplicate coordinate
# DEBUG: GPS 453 - Skipped duplicate coordinate
# DEBUG: GPS 454 - Skipped duplicate coordinate
# DEBUG: GPS 455 - Skipped duplicate coordinate
# DEBUG: GPS 456 - Skipped duplicate coordinate
# DEBUG: GPS 457 - Skipped duplicate coordinate
# DEBUG: GPS 458 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -1.330m, Lane probs: ['0.376', '0.578', '0.046'], Best: 2
# DEBUG: GPS 459 - Mapped to lane 2 (conf: 0.578, offset: -1.330m)
# DEBUG: GPS 460 - Skipped duplicate coordinate
# DEBUG: GPS 461 - Skipped duplicate coordinate
# DEBUG: GPS 462 - Skipped duplicate coordinate
# DEBUG: GPS 463 - Skipped duplicate coordinate
# DEBUG: GPS 464 - Skipped duplicate coordinate
# DEBUG: GPS 465 - Skipped duplicate coordinate
# DEBUG: GPS 466 - Skipped duplicate coordinate
# DEBUG: GPS 467 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -0.721m, Lane probs: ['0.263', '0.654', '0.084'], Best: 2
# DEBUG: GPS 468 - Mapped to lane 2 (conf: 0.654, offset: -0.721m)
# DEBUG: GPS 469 - Skipped duplicate coordinate
# DEBUG: GPS 470 - Skipped duplicate coordinate
# DEBUG: GPS 471 - Skipped duplicate coordinate
# DEBUG: GPS 472 - Skipped duplicate coordinate
# DEBUG: GPS 473 - Skipped duplicate coordinate
# DEBUG: GPS 474 - Skipped duplicate coordinate
# DEBUG: GPS 475 - Skipped duplicate coordinate
# DEBUG: GPS 476 - Skipped duplicate coordinate
# DEBUG: GPS 477 - Skipped duplicate coordinate
# DEBUG: GPS 478 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -0.518m, Lane probs: ['0.229', '0.670', '0.101'], Best: 2
# DEBUG: GPS 479 - Mapped to lane 2 (conf: 0.670, offset: -0.518m)
# DEBUG: GPS 480 - Skipped duplicate coordinate
# DEBUG: GPS 481 - Skipped duplicate coordinate
# DEBUG: GPS 482 - Skipped duplicate coordinate
# DEBUG: GPS 483 - Skipped duplicate coordinate
# DEBUG: GPS 484 - Skipped duplicate coordinate
# DEBUG: GPS 485 - Skipped duplicate coordinate
# DEBUG: GPS 486 - Skipped duplicate coordinate
# DEBUG: GPS 487 - Skipped duplicate coordinate
# DEBUG: GPS 488 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -0.633m, Lane probs: ['0.248', '0.661', '0.091'], Best: 2
# DEBUG: GPS 489 - Mapped to lane 2 (conf: 0.661, offset: -0.633m)
# DEBUG: GPS 490 - Skipped duplicate coordinate
# DEBUG: GPS 491 - Skipped duplicate coordinate
# DEBUG: GPS 492 - Skipped duplicate coordinate
# DEBUG: GPS 493 - Skipped duplicate coordinate
# DEBUG: GPS 494 - Skipped duplicate coordinate
# DEBUG: GPS 495 - Skipped duplicate coordinate
# DEBUG: GPS 496 - Skipped duplicate coordinate
# DEBUG: GPS 497 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -0.196m, Lane probs: ['0.182', '0.685', '0.133'], Best: 2
# DEBUG: GPS 498 - Mapped to lane 2 (conf: 0.685, offset: -0.196m)
# DEBUG: GPS 499 - Skipped duplicate coordinate
# Mapped 11 points in this batch
# Processing batch 6: GPS points 500 to 599
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: -0.181m, Lane probs: ['0.191', '0.665', '0.144'], Best: 2
# DEBUG: GPS 500 - Mapped to lane 2 (conf: 0.665, offset: -0.181m)
# DEBUG: GPS 501 - Skipped duplicate coordinate
# DEBUG: GPS 502 - Skipped duplicate coordinate
# DEBUG: GPS 503 - Skipped duplicate coordinate
# DEBUG: GPS 504 - Skipped duplicate coordinate
# DEBUG: GPS 505 - Skipped duplicate coordinate
# DEBUG: GPS 506 - Skipped duplicate coordinate
# DEBUG: GPS 507 - Skipped duplicate coordinate
# DEBUG: GPS 508 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 0.742m, Lane probs: ['0.082', '0.652', '0.266'], Best: 2
# DEBUG: GPS 509 - Mapped to lane 2 (conf: 0.652, offset: 0.742m)
# DEBUG: GPS 510 - Skipped duplicate coordinate
# DEBUG: GPS 511 - Skipped duplicate coordinate
# DEBUG: GPS 512 - Skipped duplicate coordinate
# DEBUG: GPS 513 - Skipped duplicate coordinate
# DEBUG: GPS 514 - Skipped duplicate coordinate
# DEBUG: GPS 515 - Skipped duplicate coordinate
# DEBUG: GPS 516 - Skipped duplicate coordinate
# DEBUG: GPS 517 - Skipped duplicate coordinate
# DEBUG: GPS 518 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 1.706m, Lane probs: ['0.030', '0.516', '0.453'], Best: 2
# DEBUG: GPS 519 - Mapped to lane 2 (conf: 0.516, offset: 1.706m)
# DEBUG: GPS 520 - Skipped duplicate coordinate
# DEBUG: GPS 521 - Skipped duplicate coordinate
# DEBUG: GPS 522 - Skipped duplicate coordinate
# DEBUG: GPS 523 - Skipped duplicate coordinate
# DEBUG: GPS 524 - Skipped duplicate coordinate
# DEBUG: GPS 525 - Skipped duplicate coordinate
# DEBUG: GPS 526 - Skipped duplicate coordinate
# DEBUG: GPS 527 - Skipped duplicate coordinate
# DEBUG: GPS 528 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 2.114m, Lane probs: ['0.019', '0.443', '0.538'], Best: 3
# DEBUG: GPS 529 - Mapped to lane 3 (conf: 0.538, offset: 2.114m)
# DEBUG: GPS 530 - Skipped duplicate coordinate
# DEBUG: GPS 531 - Skipped duplicate coordinate
# DEBUG: GPS 532 - Skipped duplicate coordinate
# DEBUG: GPS 533 - Skipped duplicate coordinate
# DEBUG: GPS 534 - Skipped duplicate coordinate
# DEBUG: GPS 535 - Skipped duplicate coordinate
# DEBUG: GPS 536 - Skipped duplicate coordinate
# DEBUG: GPS 537 - Skipped duplicate coordinate
# DEBUG: GPS 538 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 3.329m, Lane probs: ['0.004', '0.205', '0.791'], Best: 3
# DEBUG: GPS 539 - Mapped to lane 3 (conf: 0.791, offset: 3.329m)
# DEBUG: GPS 540 - Skipped duplicate coordinate
# DEBUG: GPS 541 - Skipped duplicate coordinate
# DEBUG: GPS 542 - Skipped duplicate coordinate
# DEBUG: GPS 543 - Skipped duplicate coordinate
# DEBUG: GPS 544 - Skipped duplicate coordinate
# DEBUG: GPS 545 - Skipped duplicate coordinate
# DEBUG: GPS 546 - Skipped duplicate coordinate
# DEBUG: GPS 547 - Skipped duplicate coordinate
# DEBUG: GPS 548 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 5.114m, Lane probs: ['0.000', '0.059', '0.941'], Best: 3
# DEBUG: GPS 549 - Mapped to lane 3 (conf: 0.941, offset: 5.114m)
# DEBUG: GPS 550 - Skipped duplicate coordinate
# DEBUG: GPS 551 - Skipped duplicate coordinate
# DEBUG: GPS 552 - Skipped duplicate coordinate
# DEBUG: GPS 553 - Skipped duplicate coordinate
# DEBUG: GPS 554 - Skipped duplicate coordinate
# DEBUG: GPS 555 - Skipped duplicate coordinate
# DEBUG: GPS 556 - Skipped duplicate coordinate
# DEBUG: GPS 557 - Skipped duplicate coordinate
# DEBUG: GPS 558 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.515m, Lane probs: ['0.000', '0.020', '0.980'], Best: 3
# DEBUG: GPS 559 - Mapped to lane 3 (conf: 0.980, offset: 6.515m)
# DEBUG: GPS 560 - Skipped duplicate coordinate
# DEBUG: GPS 561 - Skipped duplicate coordinate
# DEBUG: GPS 562 - Skipped duplicate coordinate
# DEBUG: GPS 563 - Skipped duplicate coordinate
# DEBUG: GPS 564 - Skipped duplicate coordinate
# DEBUG: GPS 565 - Skipped duplicate coordinate
# DEBUG: GPS 566 - Skipped duplicate coordinate
# DEBUG: GPS 567 - Skipped duplicate coordinate
# DEBUG: GPS 568 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 7.722m, Lane probs: ['0.000', '0.008', '0.992'], Best: 3
# DEBUG: GPS 569 - Mapped to lane 3 (conf: 0.992, offset: 7.722m)
# DEBUG: GPS 570 - Skipped duplicate coordinate
# DEBUG: GPS 571 - Skipped duplicate coordinate
# DEBUG: GPS 572 - Skipped duplicate coordinate
# DEBUG: GPS 573 - Skipped duplicate coordinate
# DEBUG: GPS 574 - Skipped duplicate coordinate
# DEBUG: GPS 575 - Skipped duplicate coordinate
# DEBUG: GPS 576 - Skipped duplicate coordinate
# DEBUG: GPS 577 - Skipped duplicate coordinate
# DEBUG: GPS 578 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 8.398m, Lane probs: ['0.000', '0.005', '0.995'], Best: 3
# DEBUG: GPS 579 - Mapped to lane 3 (conf: 0.995, offset: 8.398m)
# DEBUG: GPS 580 - Skipped duplicate coordinate
# DEBUG: GPS 581 - Skipped duplicate coordinate
# DEBUG: GPS 582 - Skipped duplicate coordinate
# DEBUG: GPS 583 - Skipped duplicate coordinate
# DEBUG: GPS 584 - Skipped duplicate coordinate
# DEBUG: GPS 585 - Skipped duplicate coordinate
# DEBUG: GPS 586 - Skipped duplicate coordinate
# DEBUG: GPS 587 - Skipped duplicate coordinate
# DEBUG: GPS 588 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 8.949m, Lane probs: ['0.000', '0.003', '0.997'], Best: 3
# DEBUG: GPS 589 - Mapped to lane 3 (conf: 0.997, offset: 8.949m)
# DEBUG: GPS 590 - Skipped duplicate coordinate
# DEBUG: GPS 591 - Skipped duplicate coordinate
# DEBUG: GPS 592 - Skipped duplicate coordinate
# DEBUG: GPS 593 - Skipped duplicate coordinate
# DEBUG: GPS 594 - Skipped duplicate coordinate
# DEBUG: GPS 595 - Skipped duplicate coordinate
# DEBUG: GPS 596 - Skipped duplicate coordinate
# DEBUG: GPS 597 - Skipped duplicate coordinate
# DEBUG: GPS 598 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 9.213m, Lane probs: ['0.000', '0.002', '0.998'], Best: 3
# DEBUG: GPS 599 - Mapped to lane 3 (conf: 0.998, offset: 9.213m)
# Mapped 11 points in this batch
# Processing batch 7: GPS points 600 to 699
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: 8.642m, Lane probs: ['0.000', '0.004', '0.996'], Best: 3
# DEBUG: GPS 600 - Mapped to lane 3 (conf: 0.996, offset: 8.642m)
# DEBUG: GPS 601 - Skipped duplicate coordinate
# DEBUG: GPS 602 - Skipped duplicate coordinate
# DEBUG: GPS 603 - Skipped duplicate coordinate
# DEBUG: GPS 604 - Skipped duplicate coordinate
# DEBUG: GPS 605 - Skipped duplicate coordinate
# DEBUG: GPS 606 - Skipped duplicate coordinate
# DEBUG: GPS 607 - Skipped duplicate coordinate
# DEBUG: GPS 608 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 8.694m, Lane probs: ['0.000', '0.004', '0.996'], Best: 3
# DEBUG: GPS 609 - Mapped to lane 3 (conf: 0.996, offset: 8.694m)
# DEBUG: GPS 610 - Skipped duplicate coordinate
# DEBUG: GPS 611 - Skipped duplicate coordinate
# DEBUG: GPS 612 - Skipped duplicate coordinate
# DEBUG: GPS 613 - Skipped duplicate coordinate
# DEBUG: GPS 614 - Skipped duplicate coordinate
# DEBUG: GPS 615 - Skipped duplicate coordinate
# DEBUG: GPS 616 - Skipped duplicate coordinate
# DEBUG: GPS 617 - Skipped duplicate coordinate
# DEBUG: GPS 618 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 7.845m, Lane probs: ['0.000', '0.007', '0.993'], Best: 3
# DEBUG: GPS 619 - Mapped to lane 3 (conf: 0.993, offset: 7.845m)
# DEBUG: GPS 620 - Skipped duplicate coordinate
# DEBUG: GPS 621 - Skipped duplicate coordinate
# DEBUG: GPS 622 - Skipped duplicate coordinate
# DEBUG: GPS 623 - Skipped duplicate coordinate
# DEBUG: GPS 624 - Skipped duplicate coordinate
# DEBUG: GPS 625 - Skipped duplicate coordinate
# DEBUG: GPS 626 - Skipped duplicate coordinate
# DEBUG: GPS 627 - Skipped duplicate coordinate
# DEBUG: GPS 628 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.662m, Lane probs: ['0.000', '0.018', '0.982'], Best: 3
# DEBUG: GPS 629 - Mapped to lane 3 (conf: 0.982, offset: 6.662m)
# DEBUG: GPS 630 - Skipped duplicate coordinate
# DEBUG: GPS 631 - Skipped duplicate coordinate
# DEBUG: GPS 632 - Skipped duplicate coordinate
# DEBUG: GPS 633 - Skipped duplicate coordinate
# DEBUG: GPS 634 - Skipped duplicate coordinate
# DEBUG: GPS 635 - Skipped duplicate coordinate
# DEBUG: GPS 636 - Skipped duplicate coordinate
# DEBUG: GPS 637 - Skipped duplicate coordinate
# DEBUG: GPS 638 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 5.815m, Lane probs: ['0.000', '0.035', '0.965'], Best: 3
# DEBUG: GPS 639 - Mapped to lane 3 (conf: 0.965, offset: 5.815m)
# DEBUG: GPS 640 - Skipped duplicate coordinate
# DEBUG: GPS 641 - Skipped duplicate coordinate
# DEBUG: GPS 642 - Skipped duplicate coordinate
# DEBUG: GPS 643 - Skipped duplicate coordinate
# DEBUG: GPS 644 - Skipped duplicate coordinate
# DEBUG: GPS 645 - Skipped duplicate coordinate
# DEBUG: GPS 646 - Skipped duplicate coordinate
# DEBUG: GPS 647 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 5.261m, Lane probs: ['0.000', '0.053', '0.947'], Best: 3
# DEBUG: GPS 648 - Mapped to lane 3 (conf: 0.947, offset: 5.261m)
# DEBUG: GPS 649 - Skipped duplicate coordinate
# DEBUG: GPS 650 - Skipped duplicate coordinate
# DEBUG: GPS 651 - Skipped duplicate coordinate
# DEBUG: GPS 652 - Skipped duplicate coordinate
# DEBUG: GPS 653 - Skipped duplicate coordinate
# DEBUG: GPS 654 - Skipped duplicate coordinate
# DEBUG: GPS 655 - Skipped duplicate coordinate
# DEBUG: GPS 656 - Skipped duplicate coordinate
# DEBUG: GPS 657 - Skipped duplicate coordinate
# DEBUG: GPS 658 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 4.574m, Lane probs: ['0.001', '0.088', '0.911'], Best: 3
# DEBUG: GPS 659 - Mapped to lane 3 (conf: 0.911, offset: 4.574m)
# DEBUG: GPS 660 - Skipped duplicate coordinate
# DEBUG: GPS 661 - Skipped duplicate coordinate
# DEBUG: GPS 662 - Skipped duplicate coordinate
# DEBUG: GPS 663 - Skipped duplicate coordinate
# DEBUG: GPS 664 - Skipped duplicate coordinate
# DEBUG: GPS 665 - Skipped duplicate coordinate
# DEBUG: GPS 666 - Skipped duplicate coordinate
# DEBUG: GPS 667 - Skipped duplicate coordinate
# DEBUG: GPS 668 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 3.126m, Lane probs: ['0.000', '0.026', '0.974'], Best: 3
# DEBUG: GPS 669 - Mapped to lane 3 (conf: 0.974, offset: 3.126m)
# DEBUG: GPS 670 - Skipped duplicate coordinate
# DEBUG: GPS 671 - Skipped duplicate coordinate
# DEBUG: GPS 672 - Skipped duplicate coordinate
# DEBUG: GPS 673 - Skipped duplicate coordinate
# DEBUG: GPS 674 - Skipped duplicate coordinate
# DEBUG: GPS 675 - Skipped duplicate coordinate
# DEBUG: GPS 676 - Skipped duplicate coordinate
# DEBUG: GPS 677 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 2.593m, Lane probs: ['0.010', '0.315', '0.675'], Best: 3
# DEBUG: GPS 678 - Mapped to lane 3 (conf: 0.675, offset: 2.593m)
# DEBUG: GPS 679 - Skipped duplicate coordinate
# DEBUG: GPS 680 - Skipped duplicate coordinate
# DEBUG: GPS 681 - Skipped duplicate coordinate
# DEBUG: GPS 682 - Skipped duplicate coordinate
# DEBUG: GPS 683 - Skipped duplicate coordinate
# DEBUG: GPS 684 - Skipped duplicate coordinate
# DEBUG: GPS 685 - Skipped duplicate coordinate
# DEBUG: GPS 686 - Skipped duplicate coordinate
# DEBUG: GPS 687 - Skipped duplicate coordinate
# DEBUG: GPS 688 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 1.731m, Lane probs: ['0.029', '0.466', '0.505'], Best: 3
# DEBUG: GPS 689 - Mapped to lane 3 (conf: 0.505, offset: 1.731m)
# DEBUG: GPS 690 - Skipped duplicate coordinate
# DEBUG: GPS 691 - Skipped duplicate coordinate
# DEBUG: GPS 692 - Skipped duplicate coordinate
# DEBUG: GPS 693 - Skipped duplicate coordinate
# DEBUG: GPS 694 - Skipped duplicate coordinate
# DEBUG: GPS 695 - Skipped duplicate coordinate
# DEBUG: GPS 696 - Skipped duplicate coordinate
# DEBUG: GPS 697 - Skipped duplicate coordinate
# DEBUG: GPS 698 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 1.953m, Lane probs: ['0.023', '0.426', '0.551'], Best: 3
# DEBUG: GPS 699 - Mapped to lane 3 (conf: 0.551, offset: 1.953m)
# Mapped 11 points in this batch
# Processing batch 8: GPS points 700 to 799
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: 1.953m, Lane probs: ['0.024', '0.449', '0.527'], Best: 3
# DEBUG: GPS 700 - Mapped to lane 3 (conf: 0.527, offset: 1.953m)
# DEBUG: GPS 701 - Skipped duplicate coordinate
# DEBUG: GPS 702 - Skipped duplicate coordinate
# DEBUG: GPS 703 - Skipped duplicate coordinate
# DEBUG: GPS 704 - Skipped duplicate coordinate
# DEBUG: GPS 705 - Skipped duplicate coordinate
# DEBUG: GPS 706 - Skipped duplicate coordinate
# DEBUG: GPS 707 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 1.947m, Lane probs: ['0.000', '0.354', '0.646'], Best: 3
# DEBUG: GPS 708 - Mapped to lane 3 (conf: 0.646, offset: 1.947m)
# DEBUG: GPS 709 - Skipped duplicate coordinate
# DEBUG: GPS 710 - Skipped duplicate coordinate
# DEBUG: GPS 711 - Skipped duplicate coordinate
# DEBUG: GPS 712 - Skipped duplicate coordinate
# DEBUG: GPS 713 - Skipped duplicate coordinate
# DEBUG: GPS 714 - Skipped duplicate coordinate
# DEBUG: GPS 715 - Skipped duplicate coordinate
# DEBUG: GPS 716 - Skipped duplicate coordinate
# DEBUG: GPS 717 - Skipped duplicate coordinate
# DEBUG: GPS 718 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 1.627m, Lane probs: ['0.033', '0.484', '0.483'], Best: 2
# DEBUG: GPS 719 - Mapped to lane 2 (conf: 0.484, offset: 1.627m)
# DEBUG: GPS 720 - Skipped duplicate coordinate
# DEBUG: GPS 721 - Skipped duplicate coordinate
# DEBUG: GPS 722 - Skipped duplicate coordinate
# DEBUG: GPS 723 - Skipped duplicate coordinate
# DEBUG: GPS 724 - Skipped duplicate coordinate
# DEBUG: GPS 725 - Skipped duplicate coordinate
# DEBUG: GPS 726 - Skipped duplicate coordinate
# DEBUG: GPS 727 - Skipped duplicate coordinate
# DEBUG: GPS 728 - Skipped duplicate coordinate
# DEBUG: GPS 729 - Skipped duplicate coordinate
# DEBUG: GPS 730 - Skipped duplicate coordinate
# DEBUG: GPS 731 - Skipped duplicate coordinate
# DEBUG: GPS 732 - Skipped duplicate coordinate
# DEBUG: GPS 733 - Skipped duplicate coordinate
# DEBUG: GPS 734 - Skipped duplicate coordinate
# DEBUG: GPS 735 - Skipped duplicate coordinate
# DEBUG: GPS 736 - Skipped duplicate coordinate
# DEBUG: GPS 737 - Skipped duplicate coordinate
# DEBUG: GPS 738 - Skipped duplicate coordinate
# DEBUG: GPS 739 - Skipped duplicate coordinate
# DEBUG: GPS 740 - Skipped duplicate coordinate
# DEBUG: GPS 741 - Skipped duplicate coordinate
# DEBUG: GPS 742 - Skipped duplicate coordinate
# DEBUG: GPS 743 - Skipped duplicate coordinate
# DEBUG: GPS 744 - Skipped duplicate coordinate
# DEBUG: GPS 745 - Skipped duplicate coordinate
# DEBUG: GPS 746 - Skipped duplicate coordinate
# DEBUG: GPS 747 - Skipped duplicate coordinate
# DEBUG: GPS 748 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 1.837m, Lane probs: ['0.026', '0.493', '0.481'], Best: 2
# DEBUG: GPS 749 - Mapped to lane 2 (conf: 0.493, offset: 1.837m)
# DEBUG: GPS 750 - Skipped duplicate coordinate
# DEBUG: GPS 751 - Skipped duplicate coordinate
# DEBUG: GPS 752 - Skipped duplicate coordinate
# DEBUG: GPS 753 - Skipped duplicate coordinate
# DEBUG: GPS 754 - Skipped duplicate coordinate
# DEBUG: GPS 755 - Skipped duplicate coordinate
# DEBUG: GPS 756 - Skipped duplicate coordinate
# DEBUG: GPS 757 - Skipped duplicate coordinate
# DEBUG: GPS 758 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 2.259m, Lane probs: ['0.016', '0.417', '0.568'], Best: 3
# DEBUG: GPS 759 - Mapped to lane 3 (conf: 0.568, offset: 2.259m)
# DEBUG: GPS 760 - Skipped duplicate coordinate
# DEBUG: GPS 761 - Skipped duplicate coordinate
# DEBUG: GPS 762 - Skipped duplicate coordinate
# DEBUG: GPS 763 - Skipped duplicate coordinate
# DEBUG: GPS 764 - Skipped duplicate coordinate
# DEBUG: GPS 765 - Skipped duplicate coordinate
# DEBUG: GPS 766 - Skipped duplicate coordinate
# DEBUG: GPS 767 - Skipped duplicate coordinate
# DEBUG: GPS 768 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 3.592m, Lane probs: ['0.003', '0.174', '0.824'], Best: 3
# DEBUG: GPS 769 - Mapped to lane 3 (conf: 0.824, offset: 3.592m)
# DEBUG: GPS 770 - Skipped duplicate coordinate
# DEBUG: GPS 771 - Skipped duplicate coordinate
# DEBUG: GPS 772 - Skipped duplicate coordinate
# DEBUG: GPS 773 - Skipped duplicate coordinate
# DEBUG: GPS 774 - Skipped duplicate coordinate
# DEBUG: GPS 775 - Skipped duplicate coordinate
# DEBUG: GPS 776 - Skipped duplicate coordinate
# DEBUG: GPS 777 - Skipped duplicate coordinate
# DEBUG: GPS 778 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 4.373m, Lane probs: ['0.001', '0.102', '0.897'], Best: 3
# DEBUG: GPS 779 - Mapped to lane 3 (conf: 0.897, offset: 4.373m)
# DEBUG: GPS 780 - Skipped duplicate coordinate
# DEBUG: GPS 781 - Skipped duplicate coordinate
# DEBUG: GPS 782 - Skipped duplicate coordinate
# DEBUG: GPS 783 - Skipped duplicate coordinate
# DEBUG: GPS 784 - Skipped duplicate coordinate
# DEBUG: GPS 785 - Skipped duplicate coordinate
# DEBUG: GPS 786 - Skipped duplicate coordinate
# DEBUG: GPS 787 - Skipped duplicate coordinate
# DEBUG: GPS 788 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 5.082m, Lane probs: ['0.000', '0.061', '0.939'], Best: 3
# DEBUG: GPS 789 - Mapped to lane 3 (conf: 0.939, offset: 5.082m)
# DEBUG: GPS 790 - Skipped duplicate coordinate
# DEBUG: GPS 791 - Skipped duplicate coordinate
# DEBUG: GPS 792 - Skipped duplicate coordinate
# DEBUG: GPS 793 - Skipped duplicate coordinate
# DEBUG: GPS 794 - Skipped duplicate coordinate
# DEBUG: GPS 795 - Skipped duplicate coordinate
# DEBUG: GPS 796 - Skipped duplicate coordinate
# DEBUG: GPS 797 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 5.902m, Lane probs: ['0.000', '0.033', '0.967'], Best: 3
# DEBUG: GPS 798 - Mapped to lane 3 (conf: 0.967, offset: 5.902m)
# DEBUG: GPS 799 - Skipped duplicate coordinate
# Mapped 9 points in this batch
# Processing batch 9: GPS points 800 to 899
# OSRM returned 100 tracepoints for 100 GPS points
# DEBUG: Lateral offset: 5.497m, Lane probs: ['0.000', '0.049', '0.951'], Best: 3
# DEBUG: GPS 800 - Mapped to lane 3 (conf: 0.951, offset: 5.497m)
# DEBUG: GPS 801 - Skipped duplicate coordinate
# DEBUG: GPS 802 - Skipped duplicate coordinate
# DEBUG: GPS 803 - Skipped duplicate coordinate
# DEBUG: GPS 804 - Skipped duplicate coordinate
# DEBUG: GPS 805 - Skipped duplicate coordinate
# DEBUG: GPS 806 - Skipped duplicate coordinate
# DEBUG: GPS 807 - Skipped duplicate coordinate
# DEBUG: GPS 808 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.516m, Lane probs: ['0.000', '0.020', '0.980'], Best: 3
# DEBUG: GPS 809 - Mapped to lane 3 (conf: 0.980, offset: 6.516m)
# DEBUG: GPS 810 - Skipped duplicate coordinate
# DEBUG: GPS 811 - Skipped duplicate coordinate
# DEBUG: GPS 812 - Skipped duplicate coordinate
# DEBUG: GPS 813 - Skipped duplicate coordinate
# DEBUG: GPS 814 - Skipped duplicate coordinate
# DEBUG: GPS 815 - Skipped duplicate coordinate
# DEBUG: GPS 816 - Skipped duplicate coordinate
# DEBUG: GPS 817 - Skipped duplicate coordinate
# DEBUG: GPS 818 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.503m, Lane probs: ['0.000', '0.020', '0.979'], Best: 3
# DEBUG: GPS 819 - Mapped to lane 3 (conf: 0.979, offset: 6.503m)
# DEBUG: GPS 820 - Skipped duplicate coordinate
# DEBUG: GPS 821 - Skipped duplicate coordinate
# DEBUG: GPS 822 - Skipped duplicate coordinate
# DEBUG: GPS 823 - Skipped duplicate coordinate
# DEBUG: GPS 824 - Skipped duplicate coordinate
# DEBUG: GPS 825 - Skipped duplicate coordinate
# DEBUG: GPS 826 - Skipped duplicate coordinate
# DEBUG: GPS 827 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.780m, Lane probs: ['0.000', '0.017', '0.983'], Best: 3
# DEBUG: GPS 828 - Mapped to lane 3 (conf: 0.983, offset: 6.780m)
# DEBUG: GPS 829 - Skipped duplicate coordinate
# DEBUG: GPS 830 - Skipped duplicate coordinate
# DEBUG: GPS 831 - Skipped duplicate coordinate
# DEBUG: GPS 832 - Skipped duplicate coordinate
# DEBUG: GPS 833 - Skipped duplicate coordinate
# DEBUG: GPS 834 - Skipped duplicate coordinate
# DEBUG: GPS 835 - Skipped duplicate coordinate
# DEBUG: GPS 836 - Skipped duplicate coordinate
# DEBUG: GPS 837 - Skipped duplicate coordinate
# DEBUG: GPS 838 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 7.108m, Lane probs: ['0.000', '0.013', '0.987'], Best: 3
# DEBUG: GPS 839 - Mapped to lane 3 (conf: 0.987, offset: 7.108m)
# DEBUG: GPS 840 - Skipped duplicate coordinate
# DEBUG: GPS 841 - Skipped duplicate coordinate
# DEBUG: GPS 842 - Skipped duplicate coordinate
# DEBUG: GPS 843 - Skipped duplicate coordinate
# DEBUG: GPS 844 - Skipped duplicate coordinate
# DEBUG: GPS 845 - Skipped duplicate coordinate
# DEBUG: GPS 846 - Skipped duplicate coordinate
# DEBUG: GPS 847 - Skipped duplicate coordinate
# DEBUG: GPS 848 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 7.189m, Lane probs: ['0.000', '0.012', '0.988'], Best: 3
# DEBUG: GPS 849 - Mapped to lane 3 (conf: 0.988, offset: 7.189m)
# DEBUG: GPS 850 - Skipped duplicate coordinate
# DEBUG: GPS 851 - Skipped duplicate coordinate
# DEBUG: GPS 852 - Skipped duplicate coordinate
# DEBUG: GPS 853 - Skipped duplicate coordinate
# DEBUG: GPS 854 - Skipped duplicate coordinate
# DEBUG: GPS 855 - Skipped duplicate coordinate
# DEBUG: GPS 856 - Skipped duplicate coordinate
# DEBUG: GPS 857 - Skipped duplicate coordinate
# DEBUG: GPS 858 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.385m, Lane probs: ['0.000', '0.022', '0.978'], Best: 3
# DEBUG: GPS 859 - Mapped to lane 3 (conf: 0.978, offset: 6.385m)
# DEBUG: GPS 860 - Skipped duplicate coordinate
# DEBUG: GPS 861 - Skipped duplicate coordinate
# DEBUG: GPS 862 - Skipped duplicate coordinate
# DEBUG: GPS 863 - Skipped duplicate coordinate
# DEBUG: GPS 864 - Skipped duplicate coordinate
# DEBUG: GPS 865 - Skipped duplicate coordinate
# DEBUG: GPS 866 - Skipped duplicate coordinate
# DEBUG: GPS 867 - Skipped duplicate coordinate
# DEBUG: GPS 868 - Skipped duplicate coordinate
# DEBUG: Lateral offset: 6.306m, Lane probs: ['0.000', '0.024', '0.976'], Best: 3
# ...
# DEBUG: GPS 2452 - Skipped duplicate coordinate
# DEBUG: GPS 2453 - Skipped duplicate coordinate
# DEBUG: GPS 2454 - Skipped duplicate coordinate
# DEBUG: GPS 2455 - Skipped duplicate coordinate
# DEBUG: GPS 2456 - Skipped duplicate coordinate
# DEBUG: GPS 2457 - Skipped duplicate coordinate
# DEBUG: GPS 2458 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -1.883m, Lane probs: ['0.490', '0.485', '0.025'], Best: 1
# DEBUG: GPS 2459 - Mapped to lane 1 (conf: 0.490, offset: -1.883m)
# DEBUG: GPS 2460 - Skipped duplicate coordinate
# DEBUG: GPS 2461 - Skipped duplicate coordinate
# DEBUG: GPS 2462 - Skipped duplicate coordinate
# DEBUG: GPS 2463 - Skipped duplicate coordinate
# DEBUG: GPS 2464 - Skipped duplicate coordinate
# DEBUG: GPS 2465 - Skipped duplicate coordinate
# DEBUG: GPS 2466 - Skipped duplicate coordinate
# DEBUG: GPS 2467 - Skipped duplicate coordinate
# DEBUG: GPS 2468 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.282m, Lane probs: ['0.617', '0.368', '0.015'], Best: 1
# DEBUG: GPS 2469 - Mapped to lane 1 (conf: 0.617, offset: -2.282m)
# DEBUG: GPS 2470 - Skipped duplicate coordinate
# DEBUG: GPS 2471 - Skipped duplicate coordinate
# DEBUG: GPS 2472 - Skipped duplicate coordinate
# DEBUG: GPS 2473 - Skipped duplicate coordinate
# DEBUG: GPS 2474 - Skipped duplicate coordinate
# DEBUG: GPS 2475 - Skipped duplicate coordinate
# DEBUG: GPS 2476 - Skipped duplicate coordinate
# DEBUG: GPS 2477 - Skipped duplicate coordinate
# DEBUG: GPS 2478 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.858m, Lane probs: ['0.721', '0.272', '0.007'], Best: 1
# DEBUG: GPS 2479 - Mapped to lane 1 (conf: 0.721, offset: -2.858m)
# DEBUG: GPS 2480 - Skipped duplicate coordinate
# DEBUG: GPS 2481 - Skipped duplicate coordinate
# DEBUG: GPS 2482 - Skipped duplicate coordinate
# DEBUG: GPS 2483 - Skipped duplicate coordinate
# DEBUG: GPS 2484 - Skipped duplicate coordinate
# DEBUG: GPS 2485 - Skipped duplicate coordinate
# DEBUG: GPS 2486 - Skipped duplicate coordinate
# DEBUG: GPS 2487 - Skipped duplicate coordinate
# DEBUG: GPS 2488 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.967m, Lane probs: ['0.738', '0.255', '0.006'], Best: 1
# DEBUG: GPS 2489 - Mapped to lane 1 (conf: 0.738, offset: -2.967m)
# DEBUG: GPS 2490 - Skipped duplicate coordinate
# DEBUG: GPS 2491 - Skipped duplicate coordinate
# DEBUG: GPS 2492 - Skipped duplicate coordinate
# DEBUG: GPS 2493 - Skipped duplicate coordinate
# DEBUG: GPS 2494 - Skipped duplicate coordinate
# DEBUG: GPS 2495 - Skipped duplicate coordinate
# DEBUG: GPS 2496 - Skipped duplicate coordinate
# DEBUG: GPS 2497 - Skipped duplicate coordinate
# DEBUG: GPS 2498 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.533m, Lane probs: ['0.665', '0.325', '0.011'], Best: 1
# DEBUG: GPS 2499 - Mapped to lane 1 (conf: 0.665, offset: -2.533m)
# Mapped 11 points in this batch
# Processing batch 26: GPS points 2500 to 2590
# OSRM returned 91 tracepoints for 91 GPS points
# DEBUG: Lateral offset: -2.531m, Lane probs: ['0.643', '0.346', '0.012'], Best: 1
# DEBUG: GPS 2500 - Mapped to lane 1 (conf: 0.643, offset: -2.531m)
# DEBUG: GPS 2501 - Skipped duplicate coordinate
# DEBUG: GPS 2502 - Skipped duplicate coordinate
# DEBUG: GPS 2503 - Skipped duplicate coordinate
# DEBUG: GPS 2504 - Skipped duplicate coordinate
# DEBUG: GPS 2505 - Skipped duplicate coordinate
# DEBUG: GPS 2506 - Skipped duplicate coordinate
# DEBUG: GPS 2507 - Skipped duplicate coordinate
# DEBUG: GPS 2508 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.279m, Lane probs: ['0.617', '0.368', '0.015'], Best: 1
# DEBUG: GPS 2509 - Mapped to lane 1 (conf: 0.617, offset: -2.279m)
# DEBUG: GPS 2510 - Skipped duplicate coordinate
# DEBUG: GPS 2511 - Skipped duplicate coordinate
# DEBUG: GPS 2512 - Skipped duplicate coordinate
# DEBUG: GPS 2513 - Skipped duplicate coordinate
# DEBUG: GPS 2514 - Skipped duplicate coordinate
# DEBUG: GPS 2515 - Skipped duplicate coordinate
# DEBUG: GPS 2516 - Skipped duplicate coordinate
# DEBUG: GPS 2517 - Skipped duplicate coordinate
# DEBUG: GPS 2518 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.382m, Lane probs: ['0.637', '0.350', '0.013'], Best: 1
# DEBUG: GPS 2519 - Mapped to lane 1 (conf: 0.637, offset: -2.382m)
# DEBUG: GPS 2520 - Skipped duplicate coordinate
# DEBUG: GPS 2521 - Skipped duplicate coordinate
# DEBUG: GPS 2522 - Skipped duplicate coordinate
# DEBUG: GPS 2523 - Skipped duplicate coordinate
# DEBUG: GPS 2524 - Skipped duplicate coordinate
# DEBUG: GPS 2525 - Skipped duplicate coordinate
# DEBUG: GPS 2526 - Skipped duplicate coordinate
# DEBUG: GPS 2527 - Skipped duplicate coordinate
# DEBUG: GPS 2528 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.386m, Lane probs: ['0.637', '0.350', '0.013'], Best: 1
# DEBUG: GPS 2529 - Mapped to lane 1 (conf: 0.637, offset: -2.386m)
# DEBUG: GPS 2530 - Skipped duplicate coordinate
# DEBUG: GPS 2531 - Skipped duplicate coordinate
# DEBUG: GPS 2532 - Skipped duplicate coordinate
# DEBUG: GPS 2533 - Skipped duplicate coordinate
# DEBUG: GPS 2534 - Skipped duplicate coordinate
# DEBUG: GPS 2535 - Skipped duplicate coordinate
# DEBUG: GPS 2536 - Skipped duplicate coordinate
# DEBUG: GPS 2537 - Skipped duplicate coordinate
# DEBUG: GPS 2538 - Skipped duplicate coordinate
# DEBUG: Lateral offset: -2.568m, Lane probs: ['0.671', '0.319', '0.010'], Best: 1
# DEBUG: GPS 2539 - Mapped to lane 1 (conf: 0.671, offset: -2.568m)
# DEBUG: GPS 2540 - Skipped duplicate coordinate
# DEBUG: GPS 2541 - Skipped duplicate coordinate
# DEBUG: GPS 2542 - Skipped duplicate coordinate
# DEBUG: GPS 2543 - Skipped duplicate coordinate
# DEBUG: GPS 2544 - Skipped duplicate coordinate
# DEBUG: GPS 2545 - Skipped duplicate coordinate
# DEBUG: GPS 2546 - Skipped duplicate coordinate
# DEBUG: GPS 2547 - Skipped duplicate coordinate
# DEBUG: GPS 2548 - Skipped duplicate coordinate
# DEBUG: GPS 2549 - Skipped duplicate coordinate
# DEBUG: GPS 2550 - Skipped duplicate coordinate
# DEBUG: GPS 2551 - Skipped duplicate coordinate
# DEBUG: GPS 2552 - Skipped duplicate coordinate
# DEBUG: GPS 2553 - Skipped duplicate coordinate
# DEBUG: GPS 2554 - Skipped duplicate coordinate
# DEBUG: GPS 2555 - Skipped duplicate coordinate
# DEBUG: GPS 2556 - Skipped duplicate coordinate
# DEBUG: GPS 2557 - Skipped duplicate coordinate
# DEBUG: GPS 2558 - Skipped duplicate coordinate
# DEBUG: GPS 2559 - Skipped duplicate coordinate
# DEBUG: GPS 2560 - Skipped duplicate coordinate
# DEBUG: GPS 2561 - Skipped duplicate coordinate
# DEBUG: GPS 2562 - Skipped duplicate coordinate
# DEBUG: GPS 2563 - Skipped duplicate coordinate
# DEBUG: GPS 2564 - Skipped duplicate coordinate
# DEBUG: GPS 2565 - Skipped duplicate coordinate
# DEBUG: GPS 2566 - Skipped duplicate coordinate
# DEBUG: GPS 2567 - Skipped duplicate coordinate
# DEBUG: GPS 2568 - Skipped duplicate coordinate
# DEBUG: GPS 2569 - Skipped duplicate coordinate
# DEBUG: GPS 2570 - Skipped duplicate coordinate
# DEBUG: GPS 2571 - Skipped duplicate coordinate
# DEBUG: GPS 2572 - Skipped duplicate coordinate
# DEBUG: GPS 2573 - Skipped duplicate coordinate
# DEBUG: GPS 2574 - Skipped duplicate coordinate
# DEBUG: GPS 2575 - Skipped duplicate coordinate
# DEBUG: GPS 2576 - Skipped duplicate coordinate
# DEBUG: GPS 2577 - Skipped duplicate coordinate
# DEBUG: GPS 2578 - Skipped duplicate coordinate
# DEBUG: GPS 2579 - Skipped duplicate coordinate
# DEBUG: GPS 2580 - Skipped duplicate coordinate
# DEBUG: GPS 2581 - Skipped duplicate coordinate
# DEBUG: GPS 2582 - Skipped duplicate coordinate
# DEBUG: GPS 2583 - Skipped duplicate coordinate
# DEBUG: GPS 2584 - Skipped duplicate coordinate
# DEBUG: GPS 2585 - Skipped duplicate coordinate
# DEBUG: GPS 2586 - Skipped duplicate coordinate
# DEBUG: GPS 2587 - Skipped duplicate coordinate
# DEBUG: GPS 2588 - Skipped duplicate coordinate
# DEBUG: GPS 2589 - Skipped duplicate coordinate
# DEBUG: GPS 2590 - Skipped duplicate coordinate
# Mapped 5 points in this batch
#
# Total processing complete:
# - Input GPS points: 2591
# - Successfully mapped: 252
# - Mapping rate: 9.7%
# Creating map visualization...
#
# Final lane distribution:
# Lane 1: 43 points (17.1%)
# Lane 2: 87 points (34.5%)
# Lane 3: 122 points (48.4%)
#
# Done! Check the map visualization.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d307a3fe029a31f2ce54454f3437440 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 top: 10px; right: 10px; width: 200px; height: 180px;
#                 background-color: white; border:2px solid grey; z-index:9999;
#                 font-size:12px; padding: 10px&quot;&gt;
#     &lt;p&gt;&lt;b&gt;Lane Mapping Results&lt;/b&gt;&lt;/p&gt;
#
#     &lt;p&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt; GNSS Points&lt;/p&gt;
#     &lt;p&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt; Lane 1: 43&lt;/p&gt;
#     &lt;p&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt; Lane 2: 87&lt;/p&gt;
#     &lt;p&gt;&lt;i class=&quot;fa fa-circle&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt; Lane 3: 122&lt;/p&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d307a3fe029a31f2ce54454f3437440&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d307a3fe029a31f2ce54454f3437440 = L.map(
#                 &quot;map_2d307a3fe029a31f2ce54454f3437440&quot;,
#                 {
#                     center: [12.97371167, 77.71111833],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_424441b46680ebbcd9c2a905302514f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_424441b46680ebbcd9c2a905302514f9.addTo(map_2d307a3fe029a31f2ce54454f3437440);
#
#
#             var circle_marker_98c30945956b2087c018f95993be5297 = L.circleMarker(
#                 [12.97371167, 77.71111833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d307a3fe029a31f2ce54454f3437440);
#
#
#         var popup_b013245c27ddf7780653c8ec37507a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecbe3aec20a7bbc0e49fd5f4e39e2cd1 = $(`&lt;div id=&quot;html_ecbe3aec20a7bbc0e49fd5f4e39e2cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GNSS Point 0: 12.973712, 77.711118&lt;/div&gt;`)[0];
#                 popup_b013245c27ddf7780653c8ec37507a9e.setContent(html_ecbe3aec20a7bbc0e49fd5f4e39e2cd1);
#
#
#
#         circle_marker_98c30945956b2087c018f95993be5297.bindPopup(popup_b013245c27ddf7780653c8ec37507a9e)
#         ;
#
#
#
#
#             var circle_marker_329ad86522d7c21660e1e3b248c1d26f = L.circleMarker(
#                 [12.97371167, 77.71111833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d307a3fe029a31f2ce54454f3437440);
#
#
#         var popup_cf87c9b506dc5ea9b8bf54a13d461757 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eb0847a0a8027a1dc090c70a5122a49 = $(`&lt;div id=&quot;html_2eb0847a0a8027a1dc090c70a5122a49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GNSS Point 1: 12.973712, 77.711118&lt;/div&gt;`)[0];
#                 popup_cf87c9b506dc5ea9b8bf54a13d461757.setContent(html_2eb0847a0a8027a1dc090c70a5122a49);
#
#
#
#         circle_marker_329ad86522d7c21660e1e3b248c1d26f.bindPopup(popup_cf87c9b506dc5ea9b8bf54a13d461757)
#         ;
#
#
#
#
#             var circle_marker_cc606fb20024aa475d055a3d673b96d4 = L.circleMarker(
#                 [12.97371167, 77.71111833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &qu

# %%
# Calculate average confidence
if lane_positions:
    total_confidence = sum(lp.confidence for _, lp in lane_positions)
    avg_confidence = total_confidence / len(lane_positions)
    print(f"Total confidence sum: {total_confidence:.3f}")
    print(f"Average confidence: {avg_confidence:.3f}")
else:
    print("No lane positions to calculate confidence.")
# Out:
# Total confidence sum: 222.665
# Average confidence: 0.884
